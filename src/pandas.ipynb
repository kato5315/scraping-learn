# %%
conda install beautifulsoup4 lxml html5lib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/taichikato/opt/anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#     - html5lib
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.1               |   py38hecd8cb5_1         2.9 MB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-4.10.1-py38h50d173~ --> pkgs/main::conda-4.10.1-py38hecd8cb5_1
#
#
#
# Downloading and Extracting Packages
# conda-4.10.1         | 2.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
url = "https://finance.yahoo.com/quote/AAPL/history?p=AAPL"

# %%
data = pd.read_html(url, header=0)

# %%
data[0]
# Out:
#                                                   Date  \
# 0                                         Jun 25, 2021
# 1                                         Jun 24, 2021
# 2                                         Jun 23, 2021
# 3                                         Jun 22, 2021
# 4                                         Jun 21, 2021
# ..                                                 ...
# 96                                        Feb 09, 2021
# 97                                        Feb 08, 2021
# 98                                        Feb 05, 2021
# 99                                        Feb 05, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               133.46
# 1                                               134.45
# 2                                               133.77
# 3                                               132.13
# 4                                               130.30
# ..                                                 ...
# 96                                              136.62
# 97                                              136.03
# 98                                              137.35
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 0                                               133.89
# 1                                               134.64
# 2                                               134.32
# 3                                               134.08
# 4                                               132.41
# ..                                                 ...
# 96                                              137.88
# 97                                              136.96
# 98                                              137.42
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 0                                               132.81
# 1                                               132.93
# 2                                               133.23
# 3                                               131.62
# 4                                               129.21
# ..                                                 ...
# 96                                              135.85
# 97                                              134.92
# 98                                              135.86
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 0                                               133.11
# 1                                               133.41
# 2                                               133.70
# 3                                               133.98
# 4                                               132.30
# ..                                                 ...
# 96                                              136.01
# 97                                              136.91
# 98                                              136.76
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 0                                               133.11
# 1                                               133.41
# 2                                               133.70
# 3                                               133.98
# 4                                               132.30
# ..                                                 ...
# 96                                              135.78
# 97                                              136.68
# 98                                              136.53
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 0                                             70649973
# 1                                             68619000
# 2                                             60214200
# 3                                             74783600
# 4                                             79663300
# ..                                                 ...
# 96                                            76774200
# 97                                            71297200
# 98                                            75693800
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
# [101 rows x 7 columns]

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**    Volume
# 0  Jun 25, 2021  133.46  133.89  132.81  133.11      133.11  70649973
# 1  Jun 24, 2021  134.45  134.64  132.93  133.41      133.41  68619000
# 2  Jun 23, 2021  133.77  134.32  133.23  133.70      133.70  60214200
# 3  Jun 22, 2021  132.13  134.08  131.62  133.98      133.98  74783600
# 4  Jun 21, 2021  130.30  132.41  129.21  132.30      132.30  79663300

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Feb 09, 2021
# 97                                        Feb 08, 2021
# 98                                        Feb 05, 2021
# 99                                        Feb 05, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              136.62
# 97                                              136.03
# 98                                              137.35
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              137.88
# 97                                              136.96
# 98                                              137.42
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                              135.85
# 97                                              134.92
# 98                                              135.86
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 96                                              136.01
# 97                                              136.91
# 98                                              136.76
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 96                                              135.78
# 97                                              136.68
# 98                                              136.53
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 96                                            76774200
# 97                                            71297200
# 98                                            75693800
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0]["Adj Close**"] = pd.to_numeric(data[0]["Adj Close**"], errors="coerce")

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Feb 09, 2021
# 97                                        Feb 08, 2021
# 98                                        Feb 05, 2021
# 99                                        Feb 05, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              136.62
# 97                                              136.03
# 98                                              137.35
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              137.88
# 97                                              136.96
# 98                                              137.42
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                              135.85
# 97                                              134.92
# 98                                              135.86
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  Adj Close**  \
# 96                                              136.01       135.78
# 97                                              136.91       136.68
# 98                                              136.76       136.53
# 99                                      0.205 Dividend          NaN
# 100  *Close price adjusted for splits.**Adjusted cl...          NaN
#
#                                                 Volume
# 96                                            76774200
# 97                                            71297200
# 98                                            75693800
# 99                                      0.205 Dividend
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0].dropna(inplace=True)

# %%
data[0].tail()
# Out:
#             Date    Open    High     Low  Close*  Adj Close**    Volume
# 94  Feb 11, 2021  135.90  136.39  133.77  135.13       134.90  64280000
# 95  Feb 10, 2021  136.48  136.99  134.40  135.39       135.16  73046600
# 96  Feb 09, 2021  136.62  137.88  135.85  136.01       135.78  76774200
# 97  Feb 08, 2021  136.03  136.96  134.92  136.91       136.68  71297200
# 98  Feb 05, 2021  137.35  137.42  135.86  136.76       136.53  75693800

# %%
from datetime import datetime as dt

# %%
data[0]["Date2"] = [dt.strptime(i, "%b %d, %Y")for i in data[0]["Date"]]

# %%
data[0]["Date2"].head()
# Out:
# 0   2021-06-25
# 1   2021-06-24
# 2   2021-06-23
# 3   2021-06-22
# 4   2021-06-21
# Name: Date2, dtype: datetime64[ns]

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**    Volume  \
# 0  Jun 25, 2021  133.46  133.89  132.81  133.11       133.11  70649973
# 1  Jun 24, 2021  134.45  134.64  132.93  133.41       133.41  68619000
# 2  Jun 23, 2021  133.77  134.32  133.23  133.70       133.70  60214200
# 3  Jun 22, 2021  132.13  134.08  131.62  133.98       133.98  74783600
# 4  Jun 21, 2021  130.30  132.41  129.21  132.30       132.30  79663300
#
#        Date2
# 0 2021-06-25
# 1 2021-06-24
# 2 2021-06-23
# 3 2021-06-22
# 4 2021-06-21

# %%
data[0].set_index("Date2", inplace=True)

# %%
data[0].head()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2021-06-25  Jun 25, 2021  133.46  133.89  132.81  133.11       133.11
# 2021-06-24  Jun 24, 2021  134.45  134.64  132.93  133.41       133.41
# 2021-06-23  Jun 23, 2021  133.77  134.32  133.23  133.70       133.70
# 2021-06-22  Jun 22, 2021  132.13  134.08  131.62  133.98       133.98
# 2021-06-21  Jun 21, 2021  130.30  132.41  129.21  132.30       132.30
#
#               Volume
# Date2
# 2021-06-25  70649973
# 2021-06-24  68619000
# 2021-06-23  60214200
# 2021-06-22  74783600
# 2021-06-21  79663300

# %%
data[0]["Adj Close**"].dtype
# Out:
# dtype('float64')

# %%
data[0]["Adj Close**"].plot(title="AAPL Stock Price", grid=True)
# Out:
# <AxesSubplot:title={'center':'AAPL Stock Price'}, xlabel='Date2'>

# %%
data[0].to_csv("AAPL_Stock.csv")
